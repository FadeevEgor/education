# %%
import numpy as np
import pandas as pd

import seaborn as sns
from matplotlib import pyplot as plt

# %%
comparisons = pd.read_csv("./data/_comparisons.csv", index_col=0)

plt.figure(figsize=(10, 10))
sns.lineplot(data=comparisons)
# Out:
# <AxesSubplot:>
